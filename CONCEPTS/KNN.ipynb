# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
x = [25,63,33,42]
y = [20,120,75,200]

# %%
sns.scatterplot(x)
sns.scatterplot(y)
# Out:
# <Axes: >
